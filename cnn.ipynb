# %%
from tensorflow.python.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('x_train.shape: ', x_train.shape)
print('x_test.shape: ', x_test.shape)
print('y_train.shape: ', y_train.shape)
print('y_test.shape: ', y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 35s 0us/step
# x_train.shape:  (50000, 32, 32, 3)
# x_test.shape:  (10000, 32, 32, 3)
# y_train.shape:  (50000, 1)
# y_test.shape:  (10000, 1)

# %%
from tensorflow.python.keras.utils import to_categorical

x_train = x_train/255
x_test = x_test/255

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_train, 10)

# %%
from tensorflow.python.keras.models import Sequential

model = Sequential()

from tensorflow.python.keras.layers import Conv2D

# filters: 出力チャネル数
# strides: カーネルをずらす幅
model.add(
    Conv2D(
        filters=32,
        input_shape=(32, 32, 3),
        kernel_size=(3, 3),
        strides=(1, 1),
        padding='same',
        activation='relu'
    )
)

model.add(
    Conv2D(
        filters=32,
        kernel_size=(3, 3),
        strides=(1, 1),
        padding='same',
        activation='relu'
    )
)

from tensorflow.python.keras.layers import MaxPooling2D

model.add(MaxPooling2D(pool_size=(2, 2)))

# ニューロンの2割5分をランダムに無効にする
from tensorflow.python.keras.layers import Dropout

model.add(Dropout(0.25))

model.add(
    Conv2D(
        filters=64,
        input_shape=(32, 32, 3),
        kernel_size=(3, 3),
        strides=(1, 1),
        padding='same',
        activation='relu'
    )
)

model.add(
    Conv2D(
        filters=64,
        kernel_size=(3, 3),
        strides=(1, 1),
        padding='same',
        activation='relu'
    )
)
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

from tensorflow.python.keras.layers import Flatten

model.add(Flatten())

from tensorflow.python.keras.layers import Dense

model.add(Dense(units=512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=10, activation='softmax'))

from tensorflow.python.keras.callbacks import TensorBoard

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

tsb = TensorBoard(log_dir='./logs_cnn')

history_model1 = model.fit(
    x_train,
    y_train,
    batch_size=32,
    epochs=20,
    validation_split=0.2,
    callbacks=[tsb]
)
# Out:
# Train on 40000 samples, validate on 10000 samples
# WARNING:tensorflow:From /Users/kentahara/.pyenv/versions/anaconda3-5.2.0/envs/tensorflow/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 40000/40000 [==============================] - 156s 4ms/sample - loss: 1.5687 - acc: 0.4267 - val_loss: 1.2694 - val_acc: 0.5479
# Epoch 2/20
# 40000/40000 [==============================] - 154s 4ms/sample - loss: 1.1738 - acc: 0.5807 - val_loss: 0.9982 - val_acc: 0.6435
# Epoch 3/20
# 40000/40000 [==============================] - 153s 4ms/sample - loss: 1.0116 - acc: 0.6420 - val_loss: 0.8946 - val_acc: 0.6883
# Epoch 4/20
# 40000/40000 [==============================] - 155s 4ms/sample - loss: 0.9064 - acc: 0.6824 - val_loss: 0.8490 - val_acc: 0.6998
# Epoch 5/20
# 40000/40000 [==============================] - 478s 12ms/sample - loss: 0.8319 - acc: 0.7059 - val_loss: 0.8560 - val_acc: 0.7072
# Epoch 6/20
# 40000/40000 [==============================] - 156s 4ms/sample - loss: 0.7792 - acc: 0.7246 - val_loss: 0.7565 - val_acc: 0.7382
# Epoch 7/20
# 40000/40000 [==============================] - 156s 4ms/sample - loss: 0.7312 - acc: 0.7438 - val_loss: 0.7339 - val_acc: 0.7436
# Epoch 8/20
# 40000/40000 [==============================] - 157s 4ms/sample - loss: 0.6874 - acc: 0.7584 - val_loss: 0.7167 - val_acc: 0.7545
# Epoch 9/20
# 40000/40000 [==============================] - 154s 4ms/sample - loss: 0.6483 - acc: 0.7687 - val_loss: 0.6875 - val_acc: 0.7631
# Epoch 10/20
# 40000/40000 [==============================] - 154s 4ms/sample - loss: 0.6190 - acc: 0.7816 - val_loss: 0.6819 - val_acc: 0.7679
# Epoch 11/20
# 40000/40000 [==============================] - 156s 4ms/sample - loss: 0.5861 - acc: 0.7944 - val_loss: 0.6920 - val_acc: 0.7669
# Epoch 12/20
# 40000/40000 [==============================] - 154s 4ms/sample - loss: 0.5559 - acc: 0.8051 - val_loss: 0.6637 - val_acc: 0.7758
# Epoch 13/20
# 40000/40000 [==============================] - 156s 4ms/sample - loss: 0.5345 - acc: 0.8120 - val_loss: 0.6899 - val_acc: 0.7639
# Epoch 14/20
# 40000/40000 [==============================] - 155s 4ms/sample - loss: 0.5175 - acc: 0.8168 - val_loss: 0.6736 - val_acc: 0.7740
# Epoch 15/20
# 40000/40000 [==============================] - 155s 4ms/sample - loss: 0.4935 - acc: 0.8256 - val_loss: 0.6785 - val_acc: 0.7710
# Epoch 16/20
# 40000/40000 [==============================] - 155s 4ms/sample - loss: 0.4763 - acc: 0.8331 - val_loss: 0.6789 - val_acc: 0.7751
# Epoch 17/20
# 40000/40000 [==============================] - 154s 4ms/sample - loss: 0.4585 - acc: 0.8385 - val_loss: 0.7274 - val_acc: 0.7697
# Epoch 18/20
# 40000/40000 [==============================] - 153s 4ms/sample - loss: 0.4426 - acc: 0.8444 - val_loss: 0.7042 - val_acc: 0.7767
# Epoch 19/20
# 40000/40000 [==============================] - 153s 4ms/sample - loss: 0.4434 - acc: 0.8436 - val_loss: 0.6976 - val_acc: 0.7728
# Epoch 20/20
# 40000/40000 [==============================] - 154s 4ms/sample - loss: 0.4201 - acc: 0.8518 - val_loss: 0.7539 - val_acc: 0.7765
